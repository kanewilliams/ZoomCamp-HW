# %% [markdown]
# <a href="https://colab.research.google.com/github/kanewilliams/ZoomCamp2024-HW/blob/main/Stock%20Market%20Analytics/Module01_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install main library YFinance
# !pip install yfinance

# %% [markdown]
# # Homework for Module 1
#
# Link: https://github.com/DataTalksClub/stock-markets-analytics-zoomcamp/blob/main/cohorts/2024/homework%201.md

# %%
# IMPORTS
import numpy as np
import pandas as pd

#Fin Data Sources
import yfinance as yf
import pandas_datareader as pdr

#Data viz
import plotly.graph_objs as go
import plotly.express as px

import time
from datetime import date

# %% [markdown]
# # 1) Real GDP growth rate 💸
#
# **What is the average growth (in %) of GDP in 2023?**
#
# Download the timeseries Real Gross Domestic Product (GDPC1) from FRED (https://fred.stlouisfed.org/series/GDPC1). Calculate year-over-year (YoY) growth rate (that is, divide current value to one 4 quarters ago). Find the average YoY growth in 2023 (average from 4 YoY numbers). Round to 1 digit after the decimal point: e.g. if you get 5.66% growth => you should answer 5.7
#
# ---

# %%
# Real Gross Domestic Product (GDPC1)
#https://fred.stlouisfed.org/series/GDPC1
start='2020-01-01'
real_gdp = pdr.DataReader("GDPC1", "fred", start=start)

# %%
real_gdp.head()
# Out:
#                 GDPC1
# DATE
# 2020-01-01  20665.553
# 2020-04-01  19034.830
# 2020-07-01  20511.785
# 2020-10-01  20724.128
# 2021-01-01  20990.541

# %%
# trade last year 252 trading days
real_gdp['adj_close_last_year'] = real_gdp["GDPC1"].shift(4)
real_gdp['yoy_growth'] = real_gdp["GDPC1"] / real_gdp['adj_close_last_year'] -1

# %%
real_gdp.tail()
# Out:
#                 GDPC1  adj_close_last_year  yoy_growth
# DATE
# 2022-10-01  21989.981            21847.602    0.006517
# 2023-01-01  22112.329            21738.871    0.017179
# 2023-04-01  22225.350            21708.160    0.023825
# 2023-07-01  22490.692            21851.134    0.029269
# 2023-10-01  22679.255            21989.981    0.031345

# %%
yoy_growth_2023 = real_gdp.loc['2023-01-01':'2024-01-01']['yoy_growth'].mean()
print(f"The average yoy_growth for the 4 parts of 2023 is {yoy_growth_2023:.2%}")
# Out:
# The average yoy_growth for the 4 parts of 2023 is 2.54%

# %% [markdown]
# # 2) Inverse Treasury Yield 💸
#
# **Find the min value of (dgs10-dgs2) after since year 2000 (2000-01-01) and write it down as an answer, round to 1 digit after the decimal point.**
#
# Download DGS2 and DGS10 interest rates series (https://fred.stlouisfed.org/series/DGS2, https://fred.stlouisfed.org/series/DGS10). Join them together to one dataframe on date (you might need to read about pandas.DataFrame.join()), calculate the difference dgs10-dgs2 daily.
#
# (Additional: think about what does the "inverted yield curve" mean for the market and investors? do you see the same thing in your country/market of interest? Do you think it can be a good predictive feature for the models?)
#
#
#
# ---

# %%
start='2000-01-01'
dgs = pdr.DataReader(["DGS2", "DGS10"], "fred", start=start)

# %%
dgs.head()
# Out:
#             DGS2  DGS10
# DATE
# 2000-01-03  6.38   6.58
# 2000-01-04  6.30   6.49
# 2000-01-05  6.38   6.62
# 2000-01-06  6.35   6.57
# 2000-01-07  6.31   6.52

# %%
dgs["diff"] = dgs['DGS10'] - dgs['DGS2']
dgs.head()
# Out:
#             DGS2  DGS10  diff
# DATE
# 2000-01-03  6.38   6.58  0.20
# 2000-01-04  6.30   6.49  0.19
# 2000-01-05  6.38   6.62  0.24
# 2000-01-06  6.35   6.57  0.22
# 2000-01-07  6.31   6.52  0.21

# %%
dgs_min = dgs["diff"].min()
print(f"The average yoy_growth for the 4 parts of 2023 is {dgs_min:.1f}")
# Out:
# The average yoy_growth for the 4 parts of 2023 is -1.1

# %% [markdown]
# # Question 3. [Index] Which Index is better recently?
#
# **Compare S&P 500 and IPC Mexico indexes by the 5 year growth and write down the largest value as an answer (%)**
#
# Download on Yahoo Finance two daily index prices for S&P 500 (^GSPC, https://finance.yahoo.com/quote/%5EGSPC/) and IPC Mexico (^MXX, https://finance.yahoo.com/quote/%5EMXX/). Compare 5Y growth for both (between 2019-04-09 and 2024-04-09). Select the higher growing index and write down the growth in % (closest integer %). E.g. if ratio end/start was 2.0925 (or growth of 109.25%), you need to write down 109 as your answer.
#
# (Additional: think of other indexes and try to download stats and compare the growth? Do create 10Y and 20Y growth stats. What is an average yearly growth rate (CAGR) for each of the indexes you select?)
#
# ---

# %%
snp500_daily = yf.download(tickers = "^GSPC",
                     period = "max",
                     interval = "1d")

ipcmex_daily = yf.download(tickers = "^MXX",
                     period = "max",
                     interval = "1d")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
snp500_daily
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1927-12-30    17.660000    17.660000    17.660000    17.660000    17.660000
# 1928-01-03    17.760000    17.760000    17.760000    17.760000    17.760000
# 1928-01-04    17.719999    17.719999    17.719999    17.719999    17.719999
# 1928-01-05    17.549999    17.549999    17.549999    17.549999    17.549999
# 1928-01-06    17.660000    17.660000    17.660000    17.660000    17.660000
# ...                 ...          ...          ...          ...          ...
# 2024-04-10  5167.879883  5178.430176  5138.700195  5160.640137  5160.640137
# 2024-04-11  5172.950195  5211.779785  5138.770020  5199.060059  5199.060059
# 2024-04-12  5171.509766  5175.029785  5107.939941  5123.410156  5123.410156
# 2024-04-15  5149.669922  5168.430176  5052.470215  5061.819824  5061.819824
# 2024-04-16  5064.589844  5079.839844  5039.830078  5051.410156  5051.410156
#
#                 Volume
# Date
# ...

# %%
combined = snp500_daily.join(ipcmex_daily, lsuffix='_snp', rsuffix='_ipc')
combined["2014-04-09":"2024-04-09"]
# Out:
#                Open_snp     High_snp      Low_snp    Close_snp  Adj Close_snp  \
# Date
# 2014-04-09  1852.640015  1872.430054  1852.380005  1872.180054    1872.180054
# 2014-04-10  1872.280029  1872.530029  1830.869995  1833.079956    1833.079956
# 2014-04-11  1830.650024  1835.069946  1814.359985  1815.689941    1815.689941
# 2014-04-14  1818.180054  1834.189941  1815.800049  1830.609985    1830.609985
# 2014-04-15  1831.449951  1844.020020  1816.290039  1842.979980    1842.979980
# ...                 ...          ...          ...          ...            ...
# 2024-04-03  5194.370117  5228.750000  5194.370117  5211.490234    5211.490234
# 2024-04-04  5244.049805  5256.589844  5146.060059  5147.209961    5147.209961
# 2024-04-05  5158.950195  5222.180176  5157.209961  5204.339844    5204.339844
# 2024-04-08  5211.370117  5219.569824  5197.350098  5202.390137    5202.390137
# 2024-04-09  5217.029785  5224.810059  5160.779785  5209.910156    5209.910156
#
# ...

# %%
# prompt: Obtain the quotient between Close_snp and Close_ipc in 2024-04-09 and 2019-04-09

snp_growth = combined["Close_snp"]["2024-04-09"] / combined["Close_snp"]["2019-04-09"] - 1
print(f"The 5-year growth for S&P 500 is {snp_growth:.1%}")

ipc_growth = combined["Close_ipc"]["2024-04-09"] / combined["Close_ipc"]["2019-04-09"] - 1
print(f"The 5-year growth for IPCMEX is {ipc_growth:.1%}")
# Out:
# The 5-year growth for S&P 500 is 81.0%
# The 5-year growth for IPCMEX is 27.5%

# %%
# max growth between ...

# %% [markdown]
# # Question 4. [Stocks OHLCV] 52-weeks range ratio (2023) for the selected stocks
#
# **Find the largest range ratio [=(max-min)/max] of Adj.Close prices in 2023**
#
# Download the 2023 daily OHLCV data on Yahoo Finance for top5 stocks on earnings (https://companiesmarketcap.com/most-profitable-companies/): 2222.SR,BRK-B, AAPL, MSFT, GOOG, JPM.
#
# Here is the example data you should see in Pandas for "2222.SR": https://finance.yahoo.com/quote/2222.SR/history
#
# Calculate maximum-minimim "Adj.Close" price for each stock and divide it by the maximum "Adj.Close" value. Round the result to two decimal places (e.g. 0.1575 will be 0.16)
#
# (Additional: why this may be important for your research?)
#
# ---

# %%
tickers = ["2222.SR", "BRK-B", "AAPL", "MSFT", "GOOG", "JPM"]
ohlcv_data = yf.download(tickers = tickers,
                     start = "2023-01-01",
                     end = "2023-12-31",
                     interval = "1d")
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
ohlcv_data.columns[:15]
# Out:
# MultiIndex([('Adj Close', '2222.SR'),
#             ('Adj Close',    'AAPL'),
#             ('Adj Close',   'BRK-B'),
#             ('Adj Close',    'GOOG'),
#             ('Adj Close',     'JPM'),
#             ('Adj Close',    'MSFT'),
#             (    'Close', '2222.SR'),
#             (    'Close',    'AAPL'),
#             (    'Close',   'BRK-B'),
#             (    'Close',    'GOOG'),
#             (    'Close',     'JPM'),
#             (    'Close',    'MSFT'),
#             (     'High', '2222.SR'),
#             (     'High',    'AAPL'),
#             (     'High',   'BRK-B')],
#            names=['Price', 'Ticker'])

# %%
print("Ticker  | Largest Range Ratio")
for ticker in tickers:
    max_ratio = ohlcv_data['Adj Close', ticker].max()
    min_ratio = ohlcv_data['Adj Close', ticker].min()
    largest_range_ratio = (max_ratio - min_ratio)/max_ratio
    print(ticker.ljust(7), "|", f'{largest_range_ratio:.2f}')
# Out:
# Ticker  | Largest Range Ratio
# 2222.SR | 0.21
# BRK-B   | 0.21
# AAPL    | 0.37
# MSFT    | 0.42
# GOOG    | 0.39
# JPM     | 0.28

# %% [markdown]
# # Question 5. [Stocks] Dividend Yield
#
# Find the largest dividend yield for the same set of stocks
#
# Use the same list of companies (2222.SR,BRK-B, AAPL, MSFT, GOOG, JPM) and download all dividends paid in 2023. You can use get_actions() method or .dividends field in yfinance library (https://github.com/ranaroussi/yfinance?tab=readme-ov-file#quick-start)
#
# Sum up all dividends paid in 2023 per company and divide each value by the closing price (Adj.Close) at the last trading day of the year.
#
# Find the maximum value in % and round to 1 digit after the decimal point. (E.g., if you obtained \$1.25 dividends paid and the end year stock price is $100, the dividend yield is 1.25% -- and your answer should be equal to 1.3)
#
# ---

# %%
tickers = ["2222.SR", "BRK-B", "AAPL", "MSFT", "GOOG", "JPM"]
print("Ticker  | Largest Dividend Yield")
for ticker in tickers:
    ticker_general_data = yf.download(tickers = ticker,
                        start = "2023-01-01",
                        end = "2023-12-31",
                        interval = "1d")
    ticker_dividends = yf.Ticker(ticker).dividends

    total_dividends_2023 = ticker_dividends.loc["2023-01-01":"2023-12-31"].sum()
    largest_dividend_yield = total_dividends_2023/ticker_general_data['Adj Close']["2023-12-28"]
    print("\n", ticker.ljust(7), "|", f'{largest_dividend_yield:.3%}')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Ticker  | Largest Dividend Yield
#
#  2222.SR | 2.770%
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#  BRK-B   | 0.000%
# [*********************100%%**********************]  1 of 1 completed
#  AAPL    | 0.491%
# [*********************100%%**********************]  1 of 1 completed
#  MSFT    | 0.745%
# [*********************100%%**********************]  1 of 1 completed
#  GOOG    | 0.000%
#  JPM     | 2.407%

# %% [markdown]
# The largest dividend yield is **2222.SR** with 2.8%.
